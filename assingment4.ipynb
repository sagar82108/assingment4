# %%
#1 ans) In object-oriented programming (OOP), a class is a blueprint or template that defines the characteristics and behaviors of an object.
#       It specifies the attributes (data) and methods (functions) that an object of that class can have.

#       An object, on the other hand, is an instance of a class. It is created from the class definition and 
#       has its own unique set of attribute values that may differ from other objects created from the same class.
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating objects
person1 = Person("John", 25)
person2 = Person("Mary", 30)

# Accessing object attributes
print(person1.name)    # Output: John
print(person2.age)     # Output: 30

# Calling object methods
person1.greet()    # Output: Hello, my name is John and I am 25 years old.
person2.greet()    # Output: Hello, my name is Mary and I am 30 years old.

# %%
#2 ans ) The four pillars of object-oriented programming (OOP) are:

"""
Encapsulation: It is the technique of hiding the internal details of an object and providing a public interface to access it.
It helps in achieving data abstraction and information hiding, which makes the code more secure and easy to maintain.

Inheritance: It is the mechanism of creating a new class from an existing class, which inherits the attributes and methods of the parent class.
It promotes code reuse and helps in building complex software systems in a modular way.

Polymorphism: It is the ability of an object to take many forms. It allows objects of different classes to be treated as if they were objects of the same class.
It can be achieved through method overloading and method overriding.

Abstraction: It is the process of representing complex real-world objects as simplified models in software. 
It allows developers to focus on the essential features of an object and ignore the irrelevant details.
It helps in reducing complexity, improving code readability and maintainability."""

# %%
"""3 ans) The __init__() function is a constructor method in Python classes, which is used to initialize the objects of that class. 
          It is called automatically when a new object is created and can accept parameters to set the initial state of the object's attributes."""

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def get_info(self):
        return f"My name is {self.name} and I am {self.age} years old."
person1 = Person("John", 30)
print(person1.get_info())

# %%
"""4 ans ) In object-oriented programming, the self keyword refers to the current instance of the class.
           It is used to access the attributes and methods of an object from within the class."""
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        
    def get_info(self):
        return f"This car is a {self.year} {self.make} {self.model}."
    
"""In this example, the self keyword is used in both the __init__() and get_info() methods. In the __init__() method, self is used to set the values of the make, model,
and year attributes for the specific instance of the Car class.In the get_info() method, self is used to access the make, model, 
and year attributes of the specific instance of the Car class. This allows the method to return a string that contains information about the specific instance of the class."""

# %%
"""5 ans ) Inheritance is a concept in object-oriented programming where a class can inherit properties and behavior from another class, 
           called the parent class or base class.The class that inherits these properties and behavior is called the child class or derived class."""
Single inheritance: When a child class inherits properties and behavior from a single parent class.
class Animal:
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        pass

class Dog(Animal):
    def speak(self):
        return "Woof!"
    
    
#  Multiple inheritance: When a child class inherits properties and behavior from multiple parent classes.
class Animal:
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        pass

class CanSwim:
    def swim(self):
        return "I can swim!"

class Duck(Animal, CanSwim):
    def speak(self):
        return "Quack!"
    
#  Hierarchical inheritance: When multiple child classes inherit from a single parent class.
class Animal:
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        pass

class Cat(Animal):
    def speak(self):
        return "Meow!"

class Dog(Animal):
    def speak(self):
        return "Woof!"
    
#  Multilevel inheritance: When a child class inherits from a parent class, which in turn inherits from another parent class.
class Animal:
    def __init__(self, name):
        self.name = name
    
    def speak(self):
        pass

class Mammal(Animal):
    def give_birth(self):
        return "I give birth to live young."

class Dog(Mammal):
    def speak(self):
        return "Woof!"
